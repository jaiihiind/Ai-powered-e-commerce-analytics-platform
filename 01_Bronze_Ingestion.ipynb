# %%
spark.sql("""
CREATE CATALOG IF NOT EXISTS ecommerce_ai
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.bronze
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.silver
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.gold
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.ai
""")
# Out:
# DataFrame[]

# %%
import os

print(os.getcwd())
# Out:
# /Workspace/Users/rishavray05@gmail.com/Ai agent amazon/data

# %%
import os

print(os.listdir("."))
# Out:
# ['P  L March 2021.csv', 'Cloud Warehouse Compersion Chart.csv', 'Amazon Sale Report.csv', 'Expense IIGF.csv', 'Sale Report.csv', 'DATABRICKS_SETUP.md', 'International sale Report.csv', 'May-2022.csv', '01_Bronze_Ingestion.ipynb']

# %%
import os

print(os.listdir("."))
# Out:
# ['Expense IIGF.csv', 'P  L March 2021.csv', 'Cloud Warehouse Compersion Chart.csv', 'Amazon Sale Report.csv', 'Sale Report.csv', 'DATABRICKS_SETUP.md', 'International sale Report.csv', '01_Bronze_Ingestion.ipynb', 'May-2022.csv']

# %%
# %sql
CREATE CATALOG IF NOT EXISTS ecommerce_ai;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.silver;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce_ai.ai;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
